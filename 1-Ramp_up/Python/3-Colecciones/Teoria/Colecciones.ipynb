# %% [markdown]
# ![imagen](./img/python.jpg)

# %% [markdown]
# # Python Collections
#
# #### Author: David Miró Asensi
#
# Collections are a way to group several elements together. In other notebooks we saw how lists work, which is the most used collection, but it's only the tip of the iceberg. With Python we have several ways to store datasets, depending on the type of data, purpose, type of access and performance.
#
# 1. [Lists](#1.-Lists)
# 2. [Tuples](#2.-Tuples)
# 3. [Dictionaries](#3.-Dictionaries)
# 4. [Sets](#4.-Sets)
# 5. [Conversions between collections](#5.-Conversions-between-collections)
# 6. [List comprehension](#6.-List-comprehension)
# 7. [Summary](#7.-Summary)

# %% [markdown]
# ## 1. Lists
# We already know quite a bit about lists. Let's review what we can do with them, as well as some new features

# %%
# Lists of numbers, strings, booleans, with repeated elements, nested lists...
nums = [6, 2, 8, 3, 4, 5, 5]
months = ["January", "February", "March"]
mix = [5, 7, "April", True, None, ["White", "Black"]]

# Length of the list
print(len(nums))

# Indexing
print(months[0])
print(months[len(months)-1])
# Out:
# 7
# January
# March

# %% [markdown]
# ### Access
# Between square brackets we introduce the index of the element we want to access

# %%
print(months[0])
print(months[-1])
# Out:
# January
# March

# %% [markdown]
# If we pose the problem the other way. We have the values of the list and what we want is to get the index of those values within the list

# %%
months.index("March")
# Out:
# 2

# %% [markdown]
# **Slicing**: we use slicing to access several consecutive elements of the list

# %%
degrees = [22, 34, 15, 26, 18, 22]

print(degrees[2:4])
print(degrees[2:5])
print(type(degrees[2:3]))
# Out:
# [15, 26]
# [15, 26, 18]
# <class 'list'>

# %%
degrees[2:3]*2
# Out:
# [15, 15]

# %% [markdown]
# ### Modify elements
# Lists are mutable, so we can modify them

# %%
print(months)

months[2] = "March"
print(months)
# Out:
# ['January', 'February', 'March']
# ['January', 'February', 'March']

# %% [markdown]
# ### Add elements
# It is added to the end of the list if we use `append`, or if we want in a specific place, using `insert`

# %%
bikes = ['honda', 'yamaha', 'suzuki']
print(bikes)

bikes.append('ducati')
print(bikes)

bikes.insert(2, 'kawasaki')
print(bikes)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'kawasaki', 'suzuki', 'ducati']

# %%
bikes = []

bikes.append('ducati')
print(bikes)
# Out:
# ['ducati']

# %% [markdown]
# ### Delete elements
# To delete elements use `remove`. If it doesn't exist, it gives an error, so be careful with this statement.
#
# Sometimes it's useful to keep the deleted element. For this we use `pop()`, which deletes the element we specify, and also returns that element so we can save it in a variable to use it later.

# %%
cars = ['VW', 'Seat', 'BMW', 'VW']
print(cars)

print(cars.remove('VW'))
print(cars)
# print(cars.remove('VW'))
# print(cars)
# Out:
# ['VW', 'Seat', 'BMW', 'VW']
# None
# ['Seat', 'BMW', 'VW']

# %%
print(cars.pop())
print(cars)
# Out:
# VW
# ['Seat', 'BMW']

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORS remove</h3>
#
#  </td></tr>
# </table>

# %%
cars = ['VW', 'Seat', 'BMW', 'VW']
cars.remove("Audi")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-28756f730322> in <module>
#       1 cars = ['VW', 'Seat', 'BMW', 'VW']
# ----> 2 cars.remove("Audi")
#
# ValueError: list.remove(x): x not in list
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Methods: sort, size, reverse order, count
# In this section we will see the most useful methods, but you can consult the rest in [this link](https://www.w3schools.com/python/python_ref_list.asp)

# %%
degrees = [22, 34, 15, 26, 18, 22]
print(degrees)
print(sorted(degrees))
print(degrees)
# Out:
# [22, 34, 15, 26, 18, 22]
# [15, 18, 22, 22, 26, 34]
# [22, 34, 15, 26, 18, 22]

# %%
degrees = [22, 34, 15, 26, 18, 22]
print(degrees)

# Sort
print(sorted(degrees))
print(degrees.sort())
print(degrees)

print(degrees.reverse())
print(degrees)

degrees.count(22)
# Out:
# [22, 34, 15, 26, 18, 22]
# [15, 18, 22, 22, 26, 34]
# None
# [15, 18, 22, 22, 26, 34]
# None
# [34, 26, 22, 22, 18, 15]
# 2

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORS index</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# Be very careful when accessing list elements. It's a very common error to access an index that doesn't exist in the list.
#
# If we're accessing the last element, instead of putting the number of its index, put `-1` instead, and thus we avoid errors

# %% [markdown]
# If we have this type of errors and don't know how to solve them, the best thing to do is print the length of the list, and all the elements.

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>List exercise</h3>
#
# Think of at least 3 people you would invite to dinner
# <ol>
#     <li>Use the guest list to print each one on screen, using a loop</li>
#     <li>Sort your guest list alphabetically</li>
#     <li>Who is the first guest on the list?</li>
#     <li>One of them calls you at the last minute, they won't be able to attend. Remove them from the list</li>
#     <li>Luckily a friend has called who wasn't going to attend and finally can. Add them to the middle of the list</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
# Starting list of guests
guests = ["Leonardo da Vinci", "Marie Curie", "Albert Einstein"]

# 1. Print each one using a loop
print("Guest list:")
for guest in guests:
    print(f"- {guest}")

# 2. Sort the list alphabetically
guests.sort()
print("\nSorted list:", guests)

# 3. Who is the first guest on the list?
# After sorting, the first guest is at index 0
first_guest = guests[0]
print(f"The first guest on the list is: {first_guest}")

# 4. One guest calls and can't attend. Let's remove them.
# Let's say Marie Curie had a laboratory emergency.
guests.remove("Marie Curie")
print("\nList after Marie Curie cancelled:", guests)

# 5. Adding a new friend to the middle of the list.
# We find the middle index using integer division (//)
new_friend = "Pablo Picasso"
middle_index = len(guests) // 2
guests.insert(middle_index, new_friend)

print(f"Final guest list (with {new_friend} in the middle):", guests)
# Out:
# Guest list:
# - Leonardo da Vinci
# - Marie Curie
# - Albert Einstein
#
# Sorted list: ['Albert Einstein', 'Leonardo da Vinci', 'Marie Curie']
# The first guest on the list is: Albert Einstein
#
# List after Marie Curie cancelled: ['Albert Einstein', 'Leonardo da Vinci']
# Final guest list (with Pablo Picasso in the middle): ['Albert Einstein', 'Pablo Picasso', 'Leonardo da Vinci']

# %% [markdown]
# ## 2. Tuples
# Very similar to lists. If in previous Notebooks we defined lists as ordered and mutable, tuples are ordered and immutable.
#
# * **Immutable**: once the tuple is created with its initial elements, it cannot be modified
# * **Ordered**: we can access its elements through the index and reorder the tuple as we wish
#
# Tuples are usually used for small collections of data that won't change throughout the program, such as constants.
#
# If lists were constructed using square brackets `[]`, tuples are constructed with parentheses `()`

# %%
first_tuple = (3, "text")
print(first_tuple)
print(type(first_tuple))
# Out:
# (3, 'text')
# <class 'tuple'>

# %% [markdown]
# Parentheses are already used to reorder operations `5 * (3 + 4)`, so you have to add a comma when defining a tuple with a single element, otherwise Python will interpret it as a number.

# %%
another_tuple = (1,)
print(another_tuple)
print(type(another_tuple))
# Out:
# (1,)
# <class 'tuple'>

# %%
nested_tuple = (1, 2, 3, ("A", "B", "C"))
print(nested_tuple)

print(nested_tuple[0])

for i in nested_tuple:
    print(i)
    
print(nested_tuple[0:2])

print(len(nested_tuple))
# Out:
# (1, 2, 3, ('A', 'B', 'C'))
# 1
# 1
# 2
# 3
# ('A', 'B', 'C')
# (1, 2)
# 4

# %%
nested_tuple = (1, 2, 3, ("A", "B", "C"))

nested_tuple[3][0]
# Out:
# 'A'

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORS tuples</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# Be careful that tuples are immutable, and once created you won't be able to modify them later

# %%
tuple_error = (1,2,3)
tuple_error[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-d9af5c266f87> in <module>
#       1 tupla_error = (1,2,3)
# ----> 2 tupla_error[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
# If we want to add elements, we can put them in another tuple and add them so they concatenate
tuple1 = (1,2,3)
tuple2 = (4,5,6)

print(tuple1 + tuple2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# ### Lists and tuples
# We can combine lists and tuples and we won't have any problem, as long as we respect the properties of each data type.

# %%
my_tuple = ("Oranges", "Lemons")
fruits = ["Apples", my_tuple, "Strawberries"]
print(fruits[0])
print(fruits[-1])
print(fruits[1][0])
# Out:
# Manzanas
# Fresas
# Naranjas

# %%
fruits.append("Peach")
print(fruits)
fruits[1].append("Another peach")
# Out:
# ['Manzanas', ('Naranjas', 'Limones'), 'Fresas', 'Melocoton', 'Melocoton']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\MIGUEL~1\AppData\Local\Temp/ipykernel_9092/1662717813.py in <module>
#       1 frutas.append("Melocoton")
#       2 print(frutas)
# ----> 3 frutas[1].append("Otro melocoton")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Tuple exercise</h3>
#
#
# <ol>
#     <li>Create a tuple with a single value. Check its type</li>
#     <li>Create another tuple with 3 elements</li>
#     <li>Add (as you can) to the first tuple, the three elements of the second</li>
#     <li>Get a fourth tuple from the first two values of the tuple created in the previous section</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
# 1. Create a tuple with a single value and check its type
# Remember: The comma is mandatory for a single-element tuple!
tup1 = (10,)
print("Type of tup1:", type(tup1))

# 2. Create another tuple with 3 elements
tup2 = ("Apple", "Banana", "Cherry")

# 3. Add the elements of the second to the first
# We use the '+' operator to concatenate them into a new tuple
tup3 = tup1 + tup2
print("Combined tuple:", tup3)

# 4. Get a fourth tuple from the first two values of tup3
# We use slicing [start:stop]. Stop is exclusive.
tup4 = tup3[0:2]
print("Fourth tuple (first two values):", tup4)
# Out:
# Type of tup1: <class 'tuple'>
# Combined tuple: (10, 'Apple', 'Banana', 'Cherry')
# Fourth tuple (first two values): (10, 'Apple')

# %% [markdown]
# ## 3. Dictionaries
# In this type of collections we can not only group data, but we also have the possibility to establish a relationship between them, with the form **key: value**.
#
# The syntax is using curly braces `{}`
#
# > dictionary_name = {key1: value1, key2: value2, key3: value3}
#
# If we saw that lists are mutable and ordered, and tuples immutable and ordered, dictionaries are:
#
# * **Mutable**: we can modify its elements
# * **Unordered**: the power of accessing dictionaries is their key-value format, not their order. Even so, the dictionary preserves the order of the elements as we insert them.
#
# Let's declare a dictionary in which we will define elements of a car

# %%
car = {"color": "Gray",
        "brand": "VW",
        "weight": 1500,
        "Automatic transmission": True,
        "Automatic transmission": False}
car
# Out:
# {'color': 'Gris', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': False}

# %%
print(type(car))
# Out:
# <class 'dict'>

# %%
car['Automatic transmission']
# Out:
# False

# %% [markdown]
# You can store all types of data: number, string, boolean, lists, tuples, dictionaries...
#
# When we declare the dictionary, we can do it in a single line `car = {"color"="Gray", "brand"...}`, although it is recommended for simplicity when reading the code, to perform this action on several lines. If we write the first element and press enter, Jupyter automatically introduces the indentation.

# %% [markdown]
# ### Access, modify, add, delete

# %%
# Access
print(car['Automatic transmission'])

# Modify
car['color'] = "White"
print(car)

# Add
car['doors'] = 4
print(car)

# Delete
del car['doors']
print(car)
# Out:
# False
# {'color': 'Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': False}
# {'color': 'Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': False, 'puertas': 4}
# {'color': 'Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': False}

# %%
print(car.keys())
print(car.values())
# Out:
# dict_keys(['color', 'marca', 'peso', 'Cambio automatico'])
# dict_values(['Blanco', 'VW', 1500, False])

# %% [markdown]
# For more detail on dictionary methods you can [consult the documentation](https://www.w3schools.com/python/python_ref_dictionary.asp)

# %%
# We can also start with an empty dictionary
store = {}
store['Address'] = "Avenue..."
store['Size'] = 250
print(store)
# Out:
# {'Direccion': 'Avenida...', 'Tamaño': 250}

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORS in dictionaries</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# If there is a key that doesn't exist in the dictionary, an error will be thrown.
#
# In this case, the error is quite intuitive: `KeyError`, it doesn't find the key

# %%
car = {"color": "Gray",
        "brand": "VW"}
car["weight"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\MIGUEL~1\AppData\Local\Temp/ipykernel_9092/675840988.py in <module>
#       1 coche = {"color": "Gris",
#       2         "marca": "VW"}
# ----> 3 coche["peso"]
#
# KeyError: 'peso'

# %% [markdown]
# **How to solve this?** You always have the option of using the `try/except` block, but in this case, dictionaries have a more elegant solution: `get(key, value if not exists)`

# %%
a = car.get("weight", "No weight")
# Out:
# No hay peso

# %%
a = car.get("ruedas", False)
if a == False:
    print("No hay ruedas")
# Out:
# No hay ruedas

# %% [markdown]
# ### Iterate
# The fact that the dictionary is not ordered does not mean that we cannot iterate its elements, since it is also an **iterable**, like lists or tuples.

# %%
car = {"color": "Gray",
        "brand": "VW"}

for i in car:
    print(i, car[i])
# Out:
# color Gris
# marca VW

# %%
for key, value in car.items():
    print(key, value)
# Out:
# color Gris
# marca VW

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Dictionary exercise</h3>
#
#
# <ol>
#     <li>Create a dictionary with the characteristics of a television: size, smarttv, brand...</li>
#     <li>Add another characteristic to the tv</li>
#     <li>Modify one of them</li>
#     <li>Print its keys, values and items on screen</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
# 1. Create a dictionary with TV characteristics
tv = {
    "brand": "Samsung",
    "size": 55,
    "smarttv": True
}

# 2. Add another characteristic
tv["resolution"] = "4K"

# 3. Modify one of them
tv["size"] = 65

# 4. Print keys, values, and items
print("Keys:", tv.keys())
print("Values:", tv.values())
print("Items:", tv.items())
# Out:
# Keys: dict_keys(['brand', 'size', 'smarttv', 'resolution'])
# Values: dict_values(['Samsung', 65, True, '4K'])
# Items: dict_items([('brand', 'Samsung'), ('size', 65), ('smarttv', True), ('resolution', '4K')])

# %% [markdown]
# ## 4. Sets
# Another *built-in* collection in Python, composed of a set of *keys*. Very similar to dictionaries. They have the following characteristics:
# * **Mutable**: we can modify them once they have been created
# * **Unordered**
# * **Unique elements**: it consists of a set of unique keys
#
# **When to use sets?** When we're looking for uniqueness in our data and we don't care about the order.
#
# I leave you here [the documentation](https://docs.python.org/2/library/sets.html) to make queries about sets
#
# Its syntax is:
# >```Python
# > my_set = {element1, element2, element3}
# >```
#
# It has a very similar syntax to dictionaries, but in this case the `:` are not used.

# %%
colors = {"red", "blue", "white"}
print(colors)

colors2 = {"red", "blue", "white", "red"}
print(colors2)

len(colors2)
# Out:
# {'rojo', 'azul', 'blanco'}
# {'rojo', 'azul', 'blanco'}
# 3

# %% [markdown]
# The elements of the set are unique, so if during the declaration, or later adding elements there was any duplicate, the set would ignore it. In fact, when you apply `len`, it shows the number of unique values it has.

# %%
days = {'day', 4}
print(days)

days = set()
days.add("Monday")
days.add("Tuesday")
print(days)

days.remove("Tuesday")
print(days)

print("Monday" in days)
print("Friday" not in days)

for i in days:
    print(i)
# Out:
# {'dia', 4}
# {'Lunes', 'Martes'}
# {'Lunes'}
# True
# True
# Lunes

# %% [markdown]
# To check if two sets have the same elements

# %%
set1 = {4,1,3,5,1,7,6,1,3}
set2 = {5,1,3,7,6}

set1 == set2
# Out:
# False

# %%
print(set1)
print(set2)
# Out:
# {1, 3, 4, 5, 6, 7}
# {1, 3, 5, 6, 7}

# %%
set1 = {1,3,5,1,7,6,1,3}
set2 = {5,1,3,10}

print(set1)
print(set2)

print(set1 & set2)
print(set1 | set2)
print(set1 - set2)
print(set2 - set1)
# Out:
# {1, 3, 5, 6, 7}
# {1, 10, 3, 5}
# {1, 3, 5}
# {1, 3, 5, 6, 7, 10}
# {6, 7}
# {10}

# %% [markdown]
# ## 5. Conversions between collections
#
# ### From list

# %%
list_1 = [1,2,3,3,3,3,3,3,3]
print(list_1)

# To tuple
tuple_1 = tuple(list_1)
print(tuple_1)

# To set
print(set(list_1))
# Out:
# [1, 2, 3, 3, 3, 3, 3, 3, 3]
# (1, 2, 3, 3, 3, 3, 3, 3, 3)
# {1, 2, 3}

# %% [markdown]
# ### From Tuple

# %%
tuple_1 = (1,2,3)
print(tuple_1)

# To list
print(list(tuple_1))

# To set
print(set(tuple_1))

# To dictionary
list_tuples = [("City", "Madrid"), ("Weather", "cloudy")]
print(dict(list_tuples))
# Out:
# (1, 2, 3)
# [1, 2, 3]
# {1, 2, 3}
# {'Ciudad': 'Madrid', 'Tiempo': 'nublado'}

# %% [markdown]
# ### From Dictionary

# %%
tuple_dict = [("City", "Madrid"), ("Weather", "cloudy")]
dict_1 = dict(tuple_dict)
print(dict_1)

# To list
print(list(dict_1))

# To tuple
print(tuple(dict_1))

# To set
print(set(dict_1))
# Out:
# {'Ciudad': 'Madrid', 'Tiempo': 'nublado'}
# ['Ciudad', 'Tiempo']
# ('Ciudad', 'Tiempo')
# {'Tiempo', 'Ciudad'}

# %%
my_list = []

for key, value in dict_1.items():
    my_list.append(key)
    my_list.append(value)

my_list
# Out:
# ['Ciudad', 'Madrid', 'Tiempo', 'nublado']

# %%
for i in dict_1:
    print(i)
for i in dict_1.keys():
    print(i)
for i in list(dict_1):
    print(i)
# Out:
# Ciudad
# Tiempo
# Ciudad
# Tiempo
# Ciudad
# Tiempo

# %% [markdown]
# It only keeps the keys, and we lose the values. To not lose the information:

# %%
print(dict_1.keys())
print(dict_1.values())
print(dict_1.items())
# Out:
# dict_keys(['Ciudad', 'Tiempo'])
# dict_values(['Madrid', 'nublado'])
# dict_items([('Ciudad', 'Madrid'), ('Tiempo', 'nublado')])

# %% [markdown]
# ### From Set

# %%
set_1 = {1,2,3}
print(set_1)

print(list(set_1))
print(tuple(set_1))
# Out:
# {1, 2, 3}
# [1, 2, 3]
# (1, 2, 3)

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORS in conversions</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# The dictionary usually causes problems when we try to perform conversions between collections, as it is the most complex structure.

# %%
my_tuple = (1,2,3)
dict(my_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-7f28c6012a4e> in <module>
#       1 mi_tupla = (1,2,3)
# ----> 2 dict(mi_tupla)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %% [markdown]
# ## 6. List comprehension
#
# Lists can also be created by comprehension (in English, *comprehension*). This has much to do with the definition of sets by comprehension from mathematics. For example, in mathematics this expression:
# $$ S = \{x^2 |\ x \in [3, 7), x \  odd\}$$
# This expression defines a set $ S = \{9, 25\}$, since the interval is open on the right, so it only comprises the numbers 3, 4, 5 and 6, but the condition says that we only take into account the odd numbers, that is, 3 and 5, and the expression at the beginning says that we take the squares. Remembering that to know if a number is even or odd we use the modulo operator in Python (`%`), this can be written (defining a list `s` instead of a set) as:

# %%
list_comp = [x**2 for x in range(3, 7) if x % 2 == 1]
print(list_comp)
# Out:
# [9, 25]

# %%
list_comp = []
for x in range(3, 7):
    if x % 2 == 1:
        list_comp.append(x**2)

# %% [markdown]
# If we have a piece of code that defines a list like this:
# ``` python
# new_list = []
# for e in old_list:
#     if filter(e):
#         new_list.append(transformation(e))
# ```
# It can be written, using comprehension, as:
# ```python
# new_list = [transformation(e) for e in old_list if filter(e)]
# ```
#
# The definition of lists by comprehension is very convenient, compact and expressive. However, we should not overuse it; if the expression we write is very complex it can become very difficult to read. In that case it would be preferable the "classic" definition of the list.
#
# Let's see this with an example. Suppose we have a list of `ages`, from which we want to obtain a new list, `adults` with those that are 21 or older. We would write:

# %%
ages = [19, 20, 18, 21, 19, 25]
print(ages)
adults = [x for x in ages if x >= 21]
print(adults)
# Out:
# [19, 20, 18, 21, 19, 25]
# [21, 25]

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>List comprehension exercise</h3>
#
# Try to define a lower_temperatures list, from the temperatures list, with temperatures lower than 27 degrees.
#
#          temperatures = [25.2, 24.9, 25.2, 26.7, 28.6, 29.5, 29.7]
#
#  </td></tr>
# </table>

# %%
temperatures = [25.2, 24.9, 25.2, 26.7, 28.6, 29.5, 29.7]

# Create lower_temperatures list with values < 27
lower_temperatures = [temp for temp in temperatures if temp < 27]

print(lower_temperatures)
# Output: [25.2, 24.9, 25.2, 26.7]
# Out:
# [25.2, 24.9, 25.2, 26.7]

# %% [markdown]
# ## 7. Summary

# %%
# Lists
print("Lists")
nums = [6, 2, 8, 3, 4, 5, 5]

# Size
print(len(nums))

# Access
print(nums[2])
print(nums[-1])

# Access by index
print(nums.index(5))
nums.append('numbers')
print(nums)

# Delete
nums.remove("numbers")
print(nums)

# Sort
nums.sort()
print(nums)

# Size of the list
print(len(nums))

# Reverse order
nums.reverse()
print(nums)

# Count of a value
print(nums.count(22))

# %%
# Tuples
first_tuple = (3, "text")

# Nesting of tuples
nested_tuple = (1, 2, 3, ("A", "B", "C"))
print(nested_tuple)

# Access is like in lists
print(nested_tuple[0])

# They are also iterable elements
for i in nested_tuple:
    print(i)
    
# Slicing also works the same
print(nested_tuple[0:2])

# Length of the tuple
print(len(nested_tuple))

# %%
# Dictionary
car = {"color": "Gray",
        "brand": "VW",
        "weight": 1500,
        "Automatic transmission": True}

print(car)

car = {"color": "Gray",
        "brand": "VW"
        }

for i in car: # This is going through the keys
    print(i) # We print the key
    print(car[i]) # We print the value
    
# Another way to iterate through the elements
for key, value in car.items():
    print(key, value)

# %%
# Sets
colors = {"red", "blue", "white"}
print(colors)

# Look what happens when we put duplicates
colors2 = {"red", "blue", "white", "red"}
print(colors2)

# Len also works here
len(colors2)

# Create an empty set. It's not created with {}, because if not, it would be a dictionary.
days = set()
print(days)

# Add elements
days.add("Monday")
days.add("Tuesday")
days.add("Wednesday")
print(days)

# Delete elements
days.remove("Wednesday")
print(days)

# Search for elements
print("Monday" in days)
print("Friday" not in days)

# It's also an iterable
for i in days:
    print(i)
